# %% [markdown]
# # Import Libraries

# %%
# Analisi dati e Visualizzazione
import pandas as pd
import matplotlib.pyplot as plt
import time
import copy

# Scikit-learn: Model Selection e Pipeline
from sklearn.model_selection import (
    train_test_split,
    ParameterGrid
)
from sklearn.pipeline import Pipeline
from sklearn.model_selection import StratifiedKFold

from pytorch_tabnet.pretraining import TabNetPretrainer
from pytorch_tabnet.tab_model import TabNetClassifier

# Metriche di Valutazione
from sklearn.metrics import (
    balanced_accuracy_score,
    confusion_matrix,
    ConfusionMatrixDisplay,
    classification_report,
)

# Deep Learning (PyTorch) e Monitoraggio
import torch

# Our packages
from support_modules.utils import *
from support_modules.plot import *
from support_modules.preprocessing import *
from support_modules.constants import *

#Utilities
import pickle


from sklearn import set_config
set_config(transform_output="pandas")

# %% [markdown]
# # Global Variables

# %%
SEED = 42
FILENAME = "../data/train.csv"

MODEL_DIR   = "../models"
PREPROC_DIR = "../preprocessing"
os.makedirs(MODEL_DIR, exist_ok=True)
os.makedirs(PREPROC_DIR, exist_ok=True)

# Cerca la GPU
if torch.backends.mps.is_available():
    print("MPS device is available.")
    device = torch.device("mps")
elif torch.cuda.is_available():
    print("CUDA device is available.")
    device = torch.device("cuda")
else:
    print("No GPU acceleration available.")
    device = torch.device("cpu")
# Out:
# CUDA device is available.

# %% [markdown]
# # Load the dataset

# %%
df = pd.read_csv(FILENAME, encoding='ISO-8859-1', sep=",")

rows = df.shape[0]
cols = df.shape[1]
print("# Righe: " + str(rows)+ " # Colonne: "+str(cols) + "\n")
# Out:
# # Righe: 148301 # Colonne: 145

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ## 1. Remove duplicates rows and columns

# %%
# Individua se esistono colonne con lo stesso nome
# Se esistono, allora se le colonne sono duplicati perfetti, droppiamo il duplicato
# Se esistono, ma nono sono perfetti duplicati, per intervenire consciamente sarebbe necessario avere maggior domain knowledge
feature_list = df.columns.to_list()
has_duplicate_cols = len(feature_list) != len(set(feature_list))
print("Ci sono colonne con lo stesso nome?", has_duplicate_cols)

if has_duplicate_cols:
    df = df.T.drop_duplicates().T


# Rimuovi righe duplicate
df.drop_duplicates(inplace=True)


##################################################
rows, cols = df.shape
print("Nuovo # Righe: " + str(rows)+ " Nuovo # Colonne: "+str(cols) + "\n")
# Out:
# Ci sono colonne con lo stesso nome? False
# Nuovo # Righe: 148301 Nuovo # Colonne: 145

# %% [markdown]
# ## 2. Label extraction and train-test splitting

# %%
X = df.drop(columns=["grade"])
y = df["grade"]

# %%
# Test set indipendente per Final Evaluation
X_train_full, X_test, y_train_full, y_test = train_test_split(
    X, y,
    test_size=0.15,
    stratify=y,
    random_state=SEED)

# %% [markdown]
# ## 3. Functions

# %%
def create_train_val_split(X, y, pipeline, test_size=0.25, random_state=42,
                          preproc_dir=PREPROC_DIR, model_dir=MODEL_DIR):
    X_train_raw, X_val_raw, Y_train, Y_val = train_test_split(
        X, y,
        test_size=test_size,
        random_state=random_state,
        stratify=y
    )

    X_train_tab = pipeline.structure_pipeline.fit_transform(X_train_raw)
    X_val_tab = pipeline.structure_pipeline.transform(X_val_raw)

    pipeline.cat_imputer.fit(X_train_tab)
    X_train_tab = pipeline.cat_imputer.transform(X_train_tab)
    X_val_tab = pipeline.cat_imputer.transform(X_val_tab)
    
    pipeline.num_imputer.fit(X_train_tab)
    X_train_tab = pipeline.num_imputer.transform(X_train_tab)
    X_val_tab = pipeline.num_imputer.transform(X_val_tab)
    
    pipeline.label_encoder.fit(X_train_tab)
    X_train_tab = pipeline.label_encoder.transform(X_train_tab)
    X_val_tab = pipeline.label_encoder.transform(X_val_tab)

    y_label_encoder = LabelEncoder()
    Y_train_encoded = y_label_encoder.fit_transform(Y_train)
    Y_val_encoded = y_label_encoder.transform(Y_val)
    
    # Convert to numpy
    X_train_np = pipeline.to_float.transform(X_train_tab)
    X_val_np = pipeline.to_float.transform(X_val_tab)
    Y_train_np = Y_train_encoded
    Y_val_np = Y_val_encoded 

    pipeline.is_fitted_ = True
    
    preproc_path = os.path.join(preproc_dir, 'tb_new_preprocessor.save')
    pipeline.save(preproc_path)
    print(f"Preprocessor salvato in: {preproc_path}")

    pipeline.y_label_encoder = y_label_encoder

    return {
        'X_train_np': X_train_np,
        'X_val_np': X_val_np,
        'Y_train_np': Y_train_np,
        'Y_val_np': Y_val_np,
        'cat_idxs': pipeline.get_cat_idxs(),
        'cat_dims': pipeline.get_cat_dims(),
        'y_label_encoder': y_label_encoder
    }

# %%
def run_tabnet_grid_search(
    param_grid,
    X_train,
    Y_train,
    X_val,
    Y_val,
    cat_idxs,
    cat_dims,
    save_path=os.path.join(MODEL_DIR, "tb_new"),
    load_best=False,
):
    best_loss = float("inf")
    best_balanced_acc = 0.0
    best_model = None
    best_params = None
    best_time = 0

    grid = list(ParameterGrid(param_grid))
    n_comb = len(grid)

    print("="*70)
    print(f"INIZIO GRID SEARCH TABNET")
    print(f"Totale combinazioni da testare: {n_comb}")
    print(f"Campioni di addestramento: {X_train.shape[0]}, Feature: {X_train.shape[1]}")
    print(f"Feature categoriche: {len(cat_idxs)}")
    print("="*70 + "\n")

    all_results = []
    for i, params in enumerate(grid):
        print("\n" + "="*70)
        print(f"[ESECUZIONE {i+1}/{n_comb}] INIZIO")
        print(f"Configurazione: {params}")
        print("="*70)

        start_time = time.time()

        # Estrazione parametri con default
        n_d = params.get('n_d', 64)
        n_a = params.get('n_a', n_d)
        n_steps = params.get('n_steps', 5)
        gamma = params.get('gamma', 1.5)
        n_independent = params.get('n_independent', 2)
        n_shared = params.get('n_shared', 2)
        epsilon = params.get('epsilon', 1e-15)
        lr = params.get('lr', 0.02)
        lambda_sparse = params.get('lambda_sparse', 1e-3)
        momentum = params.get('momentum', 0.02)
        pretraining_ratio = params.get('pretraining_ratio', 0.5)
        batch_size = params.get('batch_size', 1024)
        patience = params.get('patience', 10)
        max_epochs = params.get('epochs', 100)

        # Pre-addestramento
        print(f"\n>>> Fase 1/2: Pre-addestramento non supervisionato (max {max_epochs} epoche, pazienza={patience})...")
        pretrain_start = time.time()
        
        unsupervised_model = TabNetPretrainer(
            n_d=n_d, n_a=n_d, n_steps=n_steps, gamma=gamma,
            n_independent=n_independent, n_shared=n_shared,
            cat_idxs=cat_idxs, cat_dims=cat_dims,
            lambda_sparse=lambda_sparse,
            optimizer_fn=torch.optim.AdamW,
            optimizer_params=dict(lr=lr),
            mask_type="sparsemax",
            device_name=device.type,
            verbose=1,
            seed=SEED
        )

        unsupervised_model.fit(
            X_train=X_train,
            eval_set=[X_val],
            max_epochs=max_epochs,
            patience=patience,
            batch_size=batch_size,
            virtual_batch_size=128,
            num_workers=0,
            drop_last=False,
            pretraining_ratio=pretraining_ratio
        )
        
        pretrain_time = time.time() - pretrain_start
        print(f">>> Pre-addestramento completato in {pretrain_time:.2f}s ({pretrain_time/60:.2f}min)")

        # Addestramento
        print(f"\n>>> Fase 2/2: Addestramento supervisionato (max {max_epochs} epoche, pazienza={patience})...")
        train_start = time.time()
        
        model = TabNetClassifier(
            n_d=n_d, n_a=n_a, n_steps=n_steps, gamma=gamma,
            n_independent=n_independent, n_shared=n_shared,
            momentum=momentum,
            cat_idxs=cat_idxs, cat_dims=cat_dims,
            lambda_sparse=lambda_sparse,
            optimizer_fn=torch.optim.AdamW,
            optimizer_params=dict(lr=lr),
            scheduler_fn=torch.optim.lr_scheduler.StepLR,
            scheduler_params={"step_size":10, "gamma":0.9},
            mask_type="sparsemax",
            device_name=device.type,
            verbose=1,
            seed=SEED
        )

        model.fit(
            X_train=X_train, y_train=Y_train,
            eval_set=[(X_train, Y_train), (X_val, Y_val)],            #The last one is used for early stopping
            eval_metric=["logloss", "accuracy", "balanced_accuracy"], #The last metric is used for early stopping.
            patience=patience,
            batch_size=batch_size,
            virtual_batch_size=128,
            num_workers=0,
            drop_last=True,
            max_epochs=max_epochs,
            from_unsupervised=unsupervised_model,
            weights=1   #bilanciamento automatico inverso alla frequenza di classe
        )
        
        train_time = time.time() - train_start
        total_time = time.time() - start_time
        
        print(f">>> Addestramento supervisionato completato in {train_time:.2f}s ({train_time/60:.2f}min)")
        
        # Estrazione metriche
        val_loss = min(model.history["val_1_logloss"])
        val_acc = max(model.history["val_1_accuracy"])
        
        # Calcolo balanced accuracy
        y_pred = model.predict(X_val)
        balanced_acc = balanced_accuracy_score(Y_val, y_pred)

        all_results.append({
            **params,
            'balanced_acc': balanced_acc,
            'val_loss': val_loss,
            'total_time_min': total_time / 60
        })

        print("\n" + "-"*70)
        print(f"RISULTATI PER L'ESECUZIONE {i+1}/{n_comb}")
        print("-"*70)
        print(f"Tempo Totale:         {total_time:.2f}s ({total_time/60:.2f}min)")
        print(f"  - Pre-addestramento: {pretrain_time:.2f}s")
        print(f"  - Addestramento:     {train_time:.2f}s")
        print(f"Val Loss:             {val_loss:.6f}")
        print(f"Val Accuracy:         {val_acc:.4f}")
        print(f"Balanced Accuracy:    {balanced_acc:.4f}")
        print("-"*70)

        is_best = False
        if balanced_acc > best_balanced_acc:
            is_best = True
            prev_best = best_balanced_acc
            best_loss = val_loss
            best_balanced_acc = balanced_acc
            best_model = copy.deepcopy(model)
            best_params = params
            best_time = total_time

            saved_path = best_model.save_model(save_path)
            meta_path = save_path + "_meta.pth"
            torch.save({
                "training_time": best_time,
                "val_loss": val_loss,
                "balanced_accuracy": best_balanced_acc,
                "hyperparameters": best_params,
                "history": dict(model.history.history),
                "feature_names": list(X_train.columns) if hasattr(X_train, "columns")
                                 else [f"f{i}" for i in range(X_train.shape[1])],
            }, meta_path)

            print(f"\n TROVATO NUOVO MIGLIOR MODELLO!")
            print(f"   Balanced Accuracy: {prev_best:.4f} → {balanced_acc:.4f}")
            print(f"   Val Loss: {val_loss:.6f}")
            print(f"   Pesi salvati in: {saved_path}")
            print(f"   Meta salvati in: {meta_path}")
        else:
            print(f"\n✗ Non migliore dell'attuale (Balanced Acc: {best_balanced_acc:.4f})")

        # Riassunto a fine iterazione
        print("\n" + "="*70)
        print(f"[ESECUZIONE {i+1}/{n_comb}] COMPLETATA")
        print(f"Stato: {'✓ NUOVO MIGLIORE' if is_best else '✗ Nessun miglioramento'}")
        print(f"Miglior Balanced Acc attuale: {best_balanced_acc:.4f}")
        print(f"Miglior Val Loss attuale: {best_loss:.6f}")
        remaining = n_comb - (i + 1)
        est_time_remaining = remaining * total_time
        print(f"Esecuzioni rimanenti: {remaining}")
        print(f"Tempo stimato rimanente: {est_time_remaining/60:.1f} minuti ({est_time_remaining/3600:.1f} ore)")
        print("="*70 + "\n")

    print("\n" + "="*70)
    print("GRID SEARCH TABNET COMPLETATA")
    print("="*70)
    print(f"Miglior Balanced Accuracy: {best_balanced_acc:.4f}")
    print(f"Miglior Val Loss:          {best_loss:.6f}")
    print(f"Miglior Configurazione:    {best_params}")
    print(f"Miglior Tempo Addestramento: {best_time:.2f}s ({best_time/60:.2f}min)")
    print(f"Modello salvato in:        {save_path}.zip")
    print("="*70)

    return {
        "best_model": best_model,
        "best_params": best_params,
        "best_loss": best_loss,
        "best_balanced_acc": best_balanced_acc,
        "best_time": best_time,
        "all_results": all_results,
    }

# %% [markdown]
# ## 4. Pipeline

# %%
structure_pipeline = Pipeline([
    ('TABNET_leakage_test', ColumnDropper(columns = TABNET_leakage_test)),
    #('drop_leakage', ColumnDropper(columns=loan_performance_data_leakage + settlement_data_leakage + hardship_data_leakage + other_leakage + loan_contract_interest_rate)),
    #('drop_non_significant', ColumnDropper(columns=other_non_significant)),
    ('drop_high_nan', HighNanDropper(threshold=0.9)),
    #('drop_joint', ColumnDropper(columns=joint_and_secondary_cols)),
    #('high_correlation', HighlyCorrelatedDropper(threshold=0.95)),
    ('extract_nums', NumericExtractor(columns=number_from_string_cols)),
    ('avg_features', FeatureAverager(columns=average_cols, new_name='fico_average')),
    ('date_diff', DateDifferenceTransformer(reference_col=date_diff_reference, target_cols=date_diff_target)),
    ('rounding', RoundToIntTransformer(columns=round_to_nearest_int)),
])

complete_pipeline = CompletePipelineTabNet(
    structure_pipeline=structure_pipeline,
    random_state=SEED
)

# %%
train_val_data = create_train_val_split(X_train_full, y_train_full, complete_pipeline)

X_train_np = train_val_data['X_train_np']
X_val_np = train_val_data['X_val_np']
Y_train_np = train_val_data['Y_train_np']
Y_val_np = train_val_data['Y_val_np']
cat_idxs = train_val_data['cat_idxs']
cat_dims = train_val_data['cat_dims']


# Grid ampliata per la nuova macchina (GPU, ~3h). n_a e' legato a n_d dentro
# run_tabnet_grid_search (n_a = n_d, come gia' fa il pretrainer), quindi qui si varia solo n_d.
# batch_size 4096 -> meno step/epoca su GPU. 2(lr)*2(n_d)*2(n_steps)*2(gamma) = 16 combinazioni.
param_grid = {
    'batch_size':    [1024],
    'epochs':        [100],
    'epsilon':       [1e-15],
    'lr':            [0.01, 0.02],
    'n_d':           [16, 32, 64],
    'n_steps':       [3, 5],
    'gamma':         [1.3, 1.5],
    'n_independent': [1, 3],
    'patience':      [10],
    'lambda_sparse': [1e-4, 1e-5]
}

results = run_tabnet_grid_search(
    param_grid=param_grid,
    X_train=X_train_np,
    Y_train=Y_train_np,
    X_val=X_val_np,
    Y_val=Y_val_np,
    cat_idxs=cat_idxs,
    cat_dims=cat_dims,
    save_path=os.path.join(MODEL_DIR, "tb_new")
)

# %%
### OFFLINE CLASSIFICATION REPORT based on saved data
MODEL_PATH        = os.path.join(MODEL_DIR,   "tb_new.zip")
META_PATH         = os.path.join(MODEL_DIR,   "tb_new_meta.pth")
PREPROCESSOR_PATH = os.path.join(PREPROC_DIR, "tb_new_preprocessor.save")

# 1. Modello TabNet
best_model = TabNetClassifier()
best_model.load_model(MODEL_PATH)
print(f"Modello caricato da {MODEL_PATH}")

try:
    meta = torch.load(META_PATH, weights_only=False)
    print(f"  Iperparametri: {meta.get('hyperparameters')}")
    print(f"  Balanced acc (val, salvata): {meta.get('balanced_accuracy'):.4f}")
except Exception as e:
    print(f"  (metadati non caricati: {e})")

complete_pipeline = CompletePipelineTabNet.load(PREPROCESSOR_PATH)

# 3. LabelEncoder (useful to run Final Report with minimal previous cells re-run)
y_label_encoder = LabelEncoder().fit(y_train_full)

# 4. Preprocessing test set
X_test_np      = complete_pipeline.transform(X_test)
y_test_encoded = y_label_encoder.transform(y_test)

# 5. Evaluation
y_test_pred = best_model.predict(X_test_np)

print("\n=== FINAL CLASSIFICATION REPORT (TEST SET) ===")
print(classification_report(y_test_encoded, y_test_pred))

cm_test = confusion_matrix(y_test_encoded, y_test_pred)
fig, ax = plt.subplots(figsize=(8, 6))
ConfusionMatrixDisplay(confusion_matrix=cm_test).plot(cmap='Blues', ax=ax, values_format='d')
plt.title('Confusion Matrix - TabNet (Test Set, ricaricato)')
plt.show()

print(f"Balanced Accuracy (test): {balanced_accuracy_score(y_test_encoded, y_test_pred):.4f}")
# Out:
# /scratch.hpc/gabriele.aprile2/venv/lib/python3.11/site-packages/pytorch_tabnet/abstract_model.py:82: UserWarning: Device used : cuda
#   warnings.warn(f"Device used : {self.device}")
# /scratch.hpc/gabriele.aprile2/venv/lib/python3.11/site-packages/pytorch_tabnet/abstract_model.py:454: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   saved_state_dict = torch.load(f, map_location=self.device)
# Modello caricato da ../models/tb_new.zip
#   Iperparametri: {'batch_size': 1024, 'epochs': 100, 'epsilon': 1e-15, 'gamma': 1.3, 'lambda_sparse': 0.0001, 'lr': 0.02, 'n_d': 64, 'n_independent': 1, 'n_steps': 3, 'patience': 10}
#   Balanced acc (val, salvata): 0.7821
# Pipeline caricata da ../preprocessing/tb_new_preprocessor.save
#
# === FINAL CLASSIFICATION REPORT (TEST SET) ===
#               precision    recall  f1-score   support
#
#            0       0.88      0.87      0.87      3980
#            1       0.82      0.81      0.81      5661
#            2       0.84      0.82      0.83      5562
#            3       0.78      0.74      0.76      3189
#            4       0.68      0.77      0.72      1812
#            5       0.64      0.65      0.65      1129
#            6       0.71      0.80      0.75       913
#
#     accuracy                           0.80     22246
#    macro avg       0.76      0.78      0.77     22246
# weighted avg       0.80      0.80      0.80     22246
# Balanced Accuracy (test): 0.7799

# %%
# Andamento Loss e metriche (train vs val)
history = torch.load(os.path.join(MODEL_DIR, "tb_new_meta.pth"), weights_only=False)["history"]

fig, axes = plt.subplots(1, 3, figsize=(18, 5))

# Loss
axes[0].plot(history['loss'], label='Train loss (obiettivo ottimizzato)')
axes[0].plot(history['val_1_logloss'], label='Val logloss')
axes[0].set_xlabel('Epoca'); axes[0].set_ylabel('Loss')
axes[0].set_title('Andamento Loss'); axes[0].legend()

# Balanced accuracy train vs val
axes[1].plot(history['val_0_balanced_accuracy'], label='Train balanced acc')
axes[1].plot(history['val_1_balanced_accuracy'], label='Val balanced acc')
axes[1].set_xlabel('Epoca'); axes[1].set_ylabel('Balanced Accuracy')
axes[1].set_title('Andamento Balanced Accuracy'); axes[1].legend()

# Learning rate schedule
axes[2].plot(history['lr'])
axes[2].set_xlabel('Epoca'); axes[2].set_ylabel('LR')
axes[2].set_title('Learning Rate Schedule')

plt.tight_layout()
plt.show()

# %%
# Mask di attenzione per decision step
explain_matrix, masks = best_model.explain(X_val_np)

n_steps_used = len(masks)
fig, axes = plt.subplots(1, n_steps_used, figsize=(5 * n_steps_used, 4))
if n_steps_used == 1:
    axes = [axes]

for step_idx, mask in masks.items():
    axes[step_idx].imshow(mask[:50], aspect='auto', cmap='viridis')  # prime 50 righe del val set
    axes[step_idx].set_title(f'Mask — Decision Step {step_idx}')
    axes[step_idx].set_xlabel('Indice feature')
    axes[step_idx].set_ylabel('Campione')

plt.tight_layout()
plt.show()

# %%
MODEL_PATH        = os.path.join(MODEL_DIR,   "tb_new.zip")
PREPROCESSOR_PATH = os.path.join(PREPROC_DIR, "tb_new_preprocessor.save")

# 1. Carica il preprocessor fittato (contiene i nomi ordinati delle feature)
pipe = CompletePipelineTabNet.load(PREPROCESSOR_PATH)
feature_names = pipe.label_encoder.all_columns_

# 2. Carica il modello TabNet addestrato
model = TabNetClassifier()
model.load_model(MODEL_PATH)

# 3. Ricalcola la feature importance globale: servono dati rappresentativi in input.
X_raw = X_test
X_np = pipe.transform(X_raw)

M_explain, _ = model.explain(X_np)
importances = M_explain.sum(axis=0)
importances = importances / importances.sum()
# (equivalente: importances = model._compute_feature_importances(X_np))

assert len(feature_names) == len(importances), (
    f"Mismatch: {len(feature_names)} nomi vs {len(importances)} importanze. "
    "Preprocessor e modello provengono da versioni diverse della pipeline?"
)

# 4. Associa i nomi e visualizza
imp_df = (pd.DataFrame({"feature": feature_names, "importance": importances})
            .sort_values("importance", ascending=False)
            .reset_index(drop=True))

plt.figure(figsize=(8, max(4, len(imp_df.head(20)) * 0.3)))
plt.barh(imp_df["feature"].head(20)[::-1], imp_df["importance"].head(20)[::-1])
plt.xlabel("Importanza"); plt.title("TabNet — Feature Importance Globale (Top 20)")
plt.tight_layout(); plt.show()

imp_df.head(20)
# Out:
# Pipeline caricata da ../preprocessing/tb_new_preprocessor.save
# /scratch.hpc/gabriele.aprile2/venv/lib/python3.11/site-packages/pytorch_tabnet/abstract_model.py:82: UserWarning: Device used : cuda
#   warnings.warn(f"Device used : {self.device}")
# /scratch.hpc/gabriele.aprile2/venv/lib/python3.11/site-packages/pytorch_tabnet/abstract_model.py:454: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   saved_state_dict = torch.load(f, map_location=self.device)
#                                feature  importance
# 0          active_revolving_tradelines    0.268486
# 1    revolving_tradelines_balance_gt_0    0.256149
# 2                         fico_average    0.070746
# 3    tradelines_never_delinquent_ratio    0.065250
# 4   borrower_profile_employment_length    0.061875
# 5                 bankcard_utilization    0.057166
# 6           open_installment_loans_12m    0.044791
# 7            credit_delinquencies_2yrs    0.033750
# 8                     open_accounts_6m    0.028679
# 9                    last_payment_date    0.023655
# 10            tradelines_open_past_12m    0.016528
# 11             platform_policy_code_id    0.012944
# 12              accounts_open_past_24m    0.011765
# 13               credit_total_accounts    0.009656
# 14         open_revolving_accounts_24m    0.009185
# 15             hardship_flag_indicator    0.007175
# 16             installment_utilization    0.005619
# 17                  revolving_accounts    0.004587
# 18         total_payment_investor_side    0.004296
# 19           loan_contract_term_months    0.003214
